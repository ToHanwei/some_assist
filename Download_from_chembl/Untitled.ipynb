# %%
from chembl_webresource_client.new_client import new_client
import pandas as pd
import numpy as np

# %%
def download_chembl_ligand_ki(target_name):
    target = new_client.target
    activity = new_client.activity
    res = target.filter(target_synonym__icontains=target_name)[0]
    return activity.filter(
            target_chembl_id=res['target_chembl_id'], assay_type='B').filter(standard_type='Ki')

# %%
target = new_client.target
gene_name = 'ADORA2A'
res = target.filter(target_synonym__icontains=gene_name)

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                      cross_references           organism  \
# 0   [{'xref_id': 'P29274', 'xref_name': None, 'xre...       Homo sapiens
# 1   [{'xref_id': 'NBK23199', 'xref_name': 'Adenosi...       Mus musculus
# 2   [{'xref_id': 'P30543', 'xref_name': None, 'xre...  Rattus norvegicus
# 3   [{'xref_id': 'P46616', 'xref_name': None, 'xre...    Cavia porcellus
# 4                                                  []  Rattus norvegicus
# 5                                                  []  Rattus norvegicus
# 6                                                  []       Homo sapiens
# 7                                                  []       Homo sapiens
# 8                                                  []  Rattus norvegicus
# 9                                                  []       Homo sapiens
# 10                                                 []       Homo sapiens
# 11                                                 []       Homo sapiens
# ...

# %%
df[df['tax_id']==9606]
# Out:
#                                      cross_references      organism  \
# 0   [{'xref_id': 'P29274', 'xref_name': None, 'xre...  Homo sapiens
# 6                                                  []  Homo sapiens
# 7                                                  []  Homo sapiens
# 9                                                  []  Homo sapiens
# 10                                                 []  Homo sapiens
# 11                                                 []  Homo sapiens
#
#                         pref_name  species_group_flag target_chembl_id  \
# 0          Adenosine A2a receptor               False        CHEMBL251
# 6           Adenosine A2 receptor               False    CHEMBL2094257
# 7   Adenosine receptors; A2a & A3               False    CHEMBL2095213
# 9    Adenosine receptors; A1 & A2               False    CHEMBL2096679
# 10  Adenosine receptors; A1 & A2a               False    CHEMBL2096982
# ...

# %%
target = new_client.target
activity = new_client.activity
gene_name = 'ADORA2A'
res = target.filter(target_synonym__icontains=gene_name)[0]
ki_value = activity.filter(target_chembl_id=res['target_chembl_id'], assay_type="B").filter(standard_type="Ki")

# %%
len(ki_value)
# Out:
# 6497
